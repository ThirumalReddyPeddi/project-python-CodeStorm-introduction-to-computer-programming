# %% [markdown]
# <a href="https://colab.research.google.com/github/ThirumalReddyPeddi/project-python-CodeStorm-introduction-to-computer-programming/blob/main/3.Indexing_%26_Slicing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Indexing & Slicing**

# %% [markdown]
# ### Imagine that you are a superhero movie buff and you're trying to create a list of the most iconic Marvel characters. You have compiled a list of some of the most popular characters, but you want to narrow it down to the top 6.
#
# Here's your list of characters:
#
# marvel_words = ['Avengers', 'X-Men', 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America', 'Wolverine', 'Doctor Strange', 'Namor']

# %%
# Here's your list of characters:

marvel_words = ['Avengers', 'X-Men', 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America', 'Wolverine', 'Doctor Strange', 'Namor']

# %% [markdown]
# You want to narrow down the list to the last 6 characters in the list. These characters are:
#
# * Namor
# * Doctor Strange
# * Wolverine
# * Captain America
# * Black Widow
# * Thor

# %% [markdown]
# Write a code to slice these characters from the list

# %%
# Replace x with appropriate values
new_marvel=marvel_words[-1:-7:-1]
print(new_marvel)
# Out:
# ['Namor', 'Doctor Strange', 'Wolverine', 'Captain America', 'Black Widow', 'Thor']

# %% [markdown]
# ### Create two teams of superheroes based on their index position: one team should consist of all the characters located at even index positions, while the other team should consist of all the characters located at odd index positions.

# %%
team1 = marvel_words[0::2]    #even index positions
team2 = marvel_words[1::2]    #odd index positions

# %% [markdown]
# ####3. Store the word 'Spider-Man' in a new variable, and slice the word 'Spider' from it.

# %%
spider_man = marvel_words[index_number] # Add appropriate index number
spidey_sliced = spider_man[0:x] # Add appropriate index number
print(spidey_sliced)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6582/485996699.py in <cell line: 0>()
# ----> 1 spider_man = marvel_words[index_number] # Add appropriate index number
#       2 spidey_sliced = spider_man[0:x] # Add appropriate index number
#       3 print(spidey_sliced)
#
# NameError: name 'index_number' is not defined

# %%
spider_man = marvel_words[2] # appropriate index number
spidey_sliced = spider_man[0:6] # appropriate index number
print(spidey_sliced)

# %% [markdown]
# ####4. Store the word 'Iron-Man' in a variable and use reverse indexing to reverse it.

# %%
#Your code here
iron_man=marvel_words[index_number]
reversed_man=iron_man[::]
print(reversed_man)

# %%
iron_man=marvel_words[3]
reversed_man=iron_man[::-1]
print(reversed_man)

# %% [markdown]
# ### Imagine that you are a superhero movie buff and you're trying to create a list of the most iconic Marvel characters. You have compiled a list of some of the most popular characters, but you want to narrow it down to the top 6.
#
# Here's your list of characters:
#
# marvel_words = ['Avengers', 'X-Men', 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America', 'Wolverine', 'Doctor Strange', 'Namor']

# %%
# Here's your list of characters:

marvel_words = ['Avengers', 'X-Men', 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America', 'Wolverine', 'Doctor Strange', 'Namor']

# %% [markdown]
# You want to narrow down the list to the last 6 characters in the list. These characters are:
#
# * Namor
# * Doctor Strange
# * Wolverine
# * Captain America
# * Black Widow
# * Thor

# %% [markdown]
# Write a code to slice these characters from the list

# %%
# Replace x with appropriate values
new_marvel=marvel_words[-1:-7:-1]
print(new_marvel)
# Out:
# ['Namor', 'Doctor Strange', 'Wolverine', 'Captain America', 'Black Widow', 'Thor']

# %% [markdown]
# ### Create two teams of superheroes based on their index position: one team should consist of all the characters located at even index positions, while the other team should consist of all the characters located at odd index positions.

# %%
team1 = marvel_words[0::2]    #even index positions
team2 = marvel_words[1::2]    #odd index positions

# %% [markdown]
# ####3. Store the word 'Spider-Man' in a new variable, and slice the word 'Spider' from it.

# %%
spider_man = marvel_words[index_number] # Add appropriate index number
spidey_sliced = spider_man[0:x] # Add appropriate index number
print(spidey_sliced)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6582/485996699.py in <cell line: 0>()
# ----> 1 spider_man = marvel_words[index_number] # Add appropriate index number
#       2 spidey_sliced = spider_man[0:x] # Add appropriate index number
#       3 print(spidey_sliced)
#
# NameError: name 'index_number' is not defined

# %%
spider_man = marvel_words[2] # appropriate index number
spidey_sliced = spider_man[0:6] # appropriate index number
print(spidey_sliced)

# %% [markdown]
# ####4. Store the word 'Iron-Man' in a variable and use reverse indexing to reverse it.

# %%
#Your code here
iron_man=marvel_words[index_number]
reversed_man=iron_man[::]
print(reversed_man)

# %%
iron_man=marvel_words[3]
reversed_man=iron_man[::-1]
print(reversed_man)
